# %%
from snowexsql.api import PointMeasurements
data_type = 'depth'
site_name="Grand Mesa"

# %%
PointMeasurements().all_site_names
# Out:
# ['American River Basin',
#  'Central Ag Research Center',
#  'Senator Beck',
#  'farmers-creamers',
#  'Fairbanks',
#  None,
#  'Fraser Experimental Forest',
#  'Boise River Basin',
#  'Little Cottonwood Canyon',
#  'East River',
#  'North Slope',
#  'Jemez River',
#  'Grand Mesa',
#  'Cameron Pass',
#  'Sagehen Creek',
#  'Mammoth Lakes',
#  'Niwot Ridge']

# %%
from datetime import datetime 
# Find some density pit measurements at the Boise site in december 2019.
df = PointMeasurements.from_filter(
    site_name="Grand Mesa",
    date_less_equal=datetime(2020, 5, 31),
    date_greater_equal=datetime(2019, 12, 1),
    limit=100000
)

# Plot Example!
df.plot()

# Show off the dataframe
df

# Analysis Example - Find the bulk density 
#df['value'] = df['value'].astype(float)
#print(df['site_id', 'doi'])
# Out:
#       version_number equipment      value   latitude   longitude  \
# 0               None      None   4.054324  39.018487 -108.198193
# 1               None      None   3.939579  39.018487 -108.198192
# 2               None      None   3.786585  39.018488 -108.198191
# 3               None      None   3.748337  39.018488 -108.198190
# 4               None      None   3.863082  39.018489 -108.198189
# ...              ...       ...        ...        ...         ...
# 99995           None      None  81.157449  39.033623 -108.197483
# 99996           None      None  81.157449  39.033621 -108.197482
# 99997           None      None  81.608320  39.033618 -108.197481
# 99998           None      None  82.059191  39.033616 -108.197480
# 99999           None      None  82.284638  39.033613 -108.197479
#
#            northing        easting elevation  utm_zone  \
# 0      4.322564e+06  742570.506126      None        12
# 1      4.322564e+06  742570.586532      None        12
# 2      4.322564e+06  742570.666922      None        12
# 3      4.322564e+06  742570.747326      None        12
# 4      4.322564e+06  742570.827732      None        12
# ...             ...            ...       ...       ...
# 99995  4.324246e+06  742580.141287      None        12
# 99996  4.324245e+06  742580.254387      None        12
# 99997  4.324245e+06  742580.367394      None        12
# 99998  4.324245e+06  742580.480571      None        12
# 99999  4.324245e+06  742580.593630      None        12
#
#                                  geom  ...        date  \
# 0      POINT (742570.506 4322563.709)  ...  2020-02-08
# 1      POINT (742570.587 4322563.768)  ...  2020-02-08
# 2      POINT (742570.667 4322563.828)  ...  2020-02-08
# 3      POINT (742570.747 4322563.887)  ...  2020-02-08
# 4      POINT (742570.828 4322563.947)  ...  2020-02-08
# ...                               ...  ...         ...
# 99995  POINT (742580.141 4324245.724)  ...  2020-02-07
# 99996  POINT (742580.254 4324245.446)  ...  2020-02-07
# 99997  POINT (742580.367 4324245.169)  ...  2020-02-07
# 99998  POINT (742580.481 4324244.891)  ...  2020-02-07
# 99999  POINT (742580.594 4324244.613)  ...  2020-02-07
#
#                           time_created time_updated       id  \
# 0     2022-07-07 19:56:46.884180+00:00         None  3940262
# 1     2022-07-07 19:56:46.884180+00:00         None  3940263
# 2     2022-07-07 19:56:46.884180+00:00         None  3940264
# 3     2022-07-07 19:56:46.884180+00:00         None  3940265
# 4     2022-07-07 19:56:46.884180+00:00         None  3940266
# ...                                ...          ...      ...
# 99995 2022-07-07 19:57:21.141883+00:00         None  4040257
# 99996 2022-07-07 19:57:21.141883+00:00         None  4040258
# 99997 2022-07-07 19:57:21.141883+00:00         None  4040259
# 99998 2022-07-07 19:57:21.141883+00:00         None  4040260
# 99999 2022-07-07 19:57:21.141883+00:00         None  4040261
#
#                                         doi date_accessed  \
# 0      https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
# 1      https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
# 2      https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
# 3      https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
# 4      https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
# ...                                     ...           ...
# 99995  https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
# 99996  https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
# 99997  https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
# 99998  https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
# 99999  https://doi.org/10.5067/S5EGFLCIAB18    2022-07-07
#
#                                         instrument            type units  \
# 0      pulse EKKO Pro multi-polarization 1 GHz GPR  two_way_travel    ns
# 1      pulse EKKO Pro multi-polarization 1 GHz GPR  two_way_travel    ns
# 2      pulse EKKO Pro multi-polarization 1 GHz GPR  two_way_travel    ns
# 3      pulse EKKO Pro multi-polarization 1 GHz GPR  two_way_travel    ns
# 4      pulse EKKO Pro multi-polarization 1 GHz GPR  two_way_travel    ns
# ...                                            ...             ...   ...
# 99995  pulse EKKO Pro multi-polarization 1 GHz GPR           depth    cm
# 99996  pulse EKKO Pro multi-polarization 1 GHz GPR           depth    cm
# 99997  pulse EKKO Pro multi-polarization 1 GHz GPR           depth    cm
# 99998  pulse EKKO Pro multi-polarization 1 GHz GPR           depth    cm
# 99999  pulse EKKO Pro multi-polarization 1 GHz GPR           depth    cm
#
#              observers
# 0      Randall Bonnell
# 1      Randall Bonnell
# 2      Randall Bonnell
# 3      Randall Bonnell
# 4      Randall Bonnell
# ...                ...
# 99995  Randall Bonnell
# 99996  Randall Bonnell
# 99997  Randall Bonnell
# 99998  Randall Bonnell
# 99999  Randall Bonnell
#
# [100000 rows x 23 columns]

# %%
#print(df['site_id', 'doi'])
