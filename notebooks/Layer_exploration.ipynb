# %%
# Import the class reflecting the points table in the db
from snowexsql.api import LayerMeasurements as measurements

# Grab one measurement to see what attributes are available
df = measurements.from_filter(type="SSA", limit=1)

# Print out the results nicely
print("These are the available columns in the table:\n \n* {}\n".format('\n* '.join(df.columns)))
# Out:
# These are the available columns in the table:
#
# * depth
# * site_id
# * pit_id
# * bottom_depth
# * comments
# * sample_a
# * sample_b
# * sample_c
# * value
# * flags
# * latitude
# * longitude
# * northing
# * easting
# * elevation
# * utm_zone
# * geom
# * time
# * site_name
# * date
# * time_created
# * time_updated
# * id
# * doi
# * date_accessed
# * instrument
# * type
# * units
# * observers

# %%
from snowexsql.api import LayerMeasurements

df = LayerMeasurements.from_filter(type="density", limit=100)
df.plot(column='value', cmap='jet', vmin=10, vmax=150)
df
# Out:
#     depth site_id             pit_id  bottom_depth comments sample_a sample_b  \
# 0   100.0    7C15  COGM7C15_20200130          90.0     None     None     None
# 1    90.0    7C15  COGM7C15_20200130          80.0     None     None     None
# 2    80.0    7C15  COGM7C15_20200130          70.0     None     None     None
# 3    70.0    7C15  COGM7C15_20200130          60.0     None     None     None
# 4    60.0    7C15  COGM7C15_20200130          50.0     None     None     None
# ..    ...     ...                ...           ...      ...      ...      ...
# 95    NaN    8C31  COGM8C31_20200209           NaN     None     None     None
# 96    NaN    8C31  COGM8C31_20200209           NaN     None     None     None
# 97    NaN    8C31  COGM8C31_20200209           NaN     None     None     None
# 98    NaN    8C31  COGM8C31_20200209           NaN     None     None     None
# 99    NaN    8C31  COGM8C31_20200209           NaN     None     None     None
#
#    sample_c               value flags  ...        date  \
# 0      None               109.5  None  ...  2020-01-30
# 1      None               158.0  None  ...  2020-01-30
# 2      None               198.0  None  ...  2020-01-30
# 3      None               246.0  None  ...  2020-01-30
# 4      None               253.0  None  ...  2020-01-30
# ..      ...                 ...   ...  ...         ...
# 95     None               297.5  None  ...  2020-02-09
# 96     None  1.2000000000000002  None  ...  2020-02-09
# 97     None              1.2165  None  ...  2020-02-09
# 98     None               1.326  None  ...  2020-02-09
# 99     None               1.403  None  ...  2020-02-09
#
#                        time_created  time_updated       id  \
# 0  2024-08-15 19:56:44.530302+00:00          None  2367746
# 1  2024-08-15 19:56:44.530302+00:00          None  2367747
# 2  2024-08-15 19:56:44.530302+00:00          None  2367748
# 3  2024-08-15 19:56:44.530302+00:00          None  2367749
# 4  2024-08-15 19:56:44.530302+00:00          None  2367750
# ..                              ...           ...      ...
# 95 2024-08-15 19:56:45.936542+00:00          None  2368037
# 96 2024-08-15 19:56:45.936542+00:00          None  2368038
# 97 2024-08-15 19:56:45.936542+00:00          None  2368039
# 98 2024-08-15 19:56:45.936542+00:00          None  2368040
# 99 2024-08-15 19:56:45.936542+00:00          None  2368041
#
#                                      doi  date_accessed instrument     type  \
# 0   https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
# 1   https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
# 2   https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
# 3   https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
# 4   https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
# ..                                   ...            ...        ...      ...
# 95  https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
# 96  https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
# 97  https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
# 98  https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
# 99  https://doi.org/10.5067/DUD2VZEVBJ7S     2022-06-30       None  density
#
#    units observers
# 0   None      None
# 1   None      None
# 2   None      None
# 3   None      None
# 4   None      None
# ..   ...       ...
# 95  None      None
# 96  None      None
# 97  None      None
# 98  None      None
# 99  None      None
#
# [100 rows x 29 columns]
